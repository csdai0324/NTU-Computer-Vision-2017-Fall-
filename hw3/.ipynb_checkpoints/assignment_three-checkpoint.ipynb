# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
img = Image.open('lena.bmp')
original_lena_plt = plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)

# %%
def histogram(img):
    h = [0]*256
    height, width = img.size
    img = np.asarray(img)
    for i in range(width):
        for j in range(height):
            h[img[i][j]] += 1
    
    return h

def show_histogram(h):
    h_ = []
    for i in range(len(h)):
        if h[i] == 0:
            continue
        else:
            temp_h = [i] * int(h[i])
            h_ = h_ + temp_h
    bins = range(0, 256)
    plt.hist(h_, bins=bins, alpha=0.8, histtype='bar', color='blue', ec='blue')

def histogram_equalization(img):
    hist = histogram(img)
    height, width = img.size
    img = np.asarray(img)
    new_img = np.empty(shape=(height, width), dtype=int)
    n = height * width
    pdf = []
    cdf = []
    s = 0
    for i in range(len(hist)):
        s += (hist[i] / n) * 255
        pdf.append(hist[i] / n)
        cdf.append(s)
    for i in range(width):
        for j in range(height):
            new_img[i][j] = cdf[img[i][j]]
            
    return new_img.astype('uint8')

# %%
new_img = histogram_equalization(img)
h = histogram(img)
he = histogram(Image.fromarray(new_img, 'L'))
show_histogram(h)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-89365ad36bed> in <module>()
#       2 h = histogram(img)
#       3 he = histogram(Image.fromarray(new_img, 'L'))
# ----> 4 show_histogram(h)
#       5 new_img = Image.fromarray(new_img, 'L')
#       6 plt = plt.imshow(np.asarray(new_img), cmap='gray', vmin=0, vmax=255)
#
# <ipython-input-57-3a52788b70f3> in show_histogram(h)
#      18             h_ = h_ + temp_h
#      19     bins = range(0, 256)
# ---> 20     plt.hist(h_, bins=bins, alpha=0.8, histtype='bar', color='blue', ec='blue')
#      21
#      22 def histogram_equalization(img):
#
# AttributeError: 'AxesImage' object has no attribute 'hist'

# %%
show_histogram(he)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-a6eae1a5ed39> in <module>()
#       1 new_img = Image.fromarray(new_img, 'L')
# ----> 2 plt = plt.imshow(np.asarray(new_img), cmap='gray', vmin=0, vmax=255)
#
# AttributeError: 'AxesImage' object has no attribute 'imshow'

# %%
new_img = Image.fromarray(new_img, 'L')
plt = plt.imshow(np.asarray(new_img), cmap='gray', vmin=0, vmax=255)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-a6eae1a5ed39> in <module>()
# ----> 1 new_img = Image.fromarray(new_img, 'L')
#       2 plt = plt.imshow(np.asarray(new_img), cmap='gray', vmin=0, vmax=255)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2185             obj = obj.tostring()
#    2186
# -> 2187     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2188
#    2189
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2130             im = new(mode, (1, 1))
#    2131             im = im._new(
# -> 2132                 core.map_buffer(data, size, decoder_name, None, 0, args)
#    2133                 )
#    2134             im.readonly = 1
#
# TypeError: expected string or buffer
